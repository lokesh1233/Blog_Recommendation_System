# %%
import numpy as np
import pandas as pd
from pymongo import MongoClient
from bson.json_util import dumps
from datetime import datetime

import re, string, unicodedata, contractions, inflect

from bs4 import BeautifulSoup
import nltk
from nltk import word_tokenize, sent_tokenize
from nltk.stem import LancasterStemmer, WordNetLemmatizer, SnowballStemmer, PorterStemmer
from nltk.corpus import stopwords
from textblob import TextBlob, Word
from stemming.porter2 import stem

from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

from scipy.stats import pearsonr

from subprocess import check_output
import bson
stop = stopwords.words('english')

# %% [markdown]
# ## reading data from the file dataset

# %%
# ratings = pd.read_csv("../data/processed/rating.csv")
# users   = pd.read_csv("../data/processed/users.csv")
# blogs = pd.read_csv("../data/processed/blogs.csv")

# ratings["rating"] = ratings["rating"].astype(float)

# # ratings to pivot table
# rating_piot = pd.pivot_table(ratings, values="rating", index="userId", columns="movieId")
# df_tags = pd.DataFrame(blogs.fillna("").apply(lambda x: x[3]+x[4]+x[5]+x[6], axis=1))
# df_tags.columns = ["content"]
# df_tags['raw_data'] = df_tags["content"]

# %% [markdown]
# ## Reading data from the mongodb

# %%
def _connect_mongo(host='localhost', port=27017, username=None, password=None, db="Blog_Recommendation"):
    """ A util for making a connection to mongo """

    if username and password:
        mongo_uri = 'mongodb://%s:%s@%s:%s/%s' % (username, password, host, port, db)
        conn = MongoClient(mongo_uri)
    else:
        conn = MongoClient(host, port)


    return conn[db]


def read_mongo(db, collection, query={}, selection=None, host='localhost', port=27017, username=None, password=None, no_id=True):
    """ Read from Mongo and Store into DataFrame """

    # Connect to MongoDB
    db = _connect_mongo(host=host, port=port, username=username, password=password, db=db)

    # Make a query to the specific DB and Collection
    cursor = db[collection].find(query, selection)

    # Expand the cursor and construct the DataFrame
    df =  pd.DataFrame(list(cursor))

    # Delete the _id
    if no_id:
        del df['_id']

    return df

# %%
users = read_mongo('Blog_Recommendation',"Users", {})
blogs = read_mongo('Blog_Recommendation',"Blogs", {})
views = read_mongo('Blog_Recommendation',"Views", query={},selection={"blogid": 1, "userid" : 1, "viewedcount":1})

# %%
views["viewedcount"] = views["viewedcount"].astype(float)

# ratings to pivot table
rating_piot = pd.pivot_table(views, values="viewedcount", index="userid", columns="blogid")

data_blog = blogs.fillna("")[["content", "subtitle", "tags", "title"]]
df_tags = pd.DataFrame(data_blog["content"] + " " +data_blog["subtitle"] + " " +data_blog["tags"] + " " +data_blog["title"])

# df_tags = pd.DataFrame(blogs.fillna("").apply(lambda x: x[3]+x[4]+x[5]+x[6], axis=1))
df_tags.columns = ["content"]
df_tags['raw_data'] = df_tags["content"]

# %% [markdown]
# ## Feature extraction dataset

# %%
# ## removal of noise and contractions

# def strip_html(text):
#     soup = BeautifulSoup(text, "html.parser")
#     return soup.get_text()

# def remove_between_square_brackets(text):
#     return re.sub('\[[^]]*\]', '', text)

# def denoise_text(text):
#     text = strip_html(text)
#     text = remove_between_square_brackets(text)
#     return text

# sample = denoise_text(sample)
# # print(sample)


# def replace_contractions(text):
#     """Replace contractions in string of text"""
#     return contractions.fix(text)

# sample = replace_contractions(sample)
# # print(sample)


def replace_noise_contraction(text):
    return contractions.fix(re.sub('\[[^]]*\]', '', BeautifulSoup(text, "html.parser").get_text()))

def

# %%
# word count
df_tags['word_count'] = df_tags['content'].apply(lambda x: len(str(x).split(" ")))
# char count
df_tags['char_count'] = df_tags['content'].str.len()

# average words
def avg_word(sentence):
    words = sentence.split()
    return (sum(len(word) for word in words)/len(words))

df_tags['avg_word'] = df_tags["content"].apply(avg_word)

# stop words count
df_tags["stopwords"] = df_tags["content"].apply(lambda x: len([y for y in x.split() if y in stop]))

#hash tags
df_tags["hashtags"] = df_tags["content"].apply(lambda x: len([y for y in x.split() if y.startswith('#')]))

#numerics
df_tags["numerics"] = df_tags["content"].apply(lambda x: len([y for y in x.split() if y.isdigit()]))

#uppercase
df_tags["uppercase"] = df_tags["content"].apply(lambda x: len([y for y in x.split() if y.isupper()]))

# %% [markdown]
# ## Preprocessing dataset

# %%
words = nltk.word_tokenize(sample)
# print(words)

# %%
def remove_non_ascii(words):
    """Remove non-ASCII characters from list of tokenized words"""
    new_words = []
    for word in words:
        new_word = unicodedata.normalize('NFKD', word).encode('ascii', 'ignore').decode('utf-8', 'ignore')
        new_words.append(new_word)
    return new_words

def to_lowercase(words):
    """Convert all characters to lowercase from list of tokenized words"""
    new_words = []
    for word in words:
        new_word = word.lower()
        new_words.append(new_word)
    return new_words

def remove_punctuation(words):
    """Remove punctuation from list of tokenized words"""
    new_words = []
    for word in words:
        new_word = re.sub(r'[^\w\s]', '', word)
        if new_word != '':
            new_words.append(new_word)
    return new_words

def replace_numbers(words):
    """Replace all interger occurrences in list of tokenized words with textual representation"""
    p = inflect.engine()
    new_words = []
    for word in words:
        if word.isdigit():
            new_word = p.number_to_words(word)
            new_words.append(new_word)
        else:
            new_words.append(word)
    return new_words

def remove_stopwords(words):
    """Remove stop words from list of tokenized words"""
    new_words = []
    for word in words:
        if word not in stopwords.words('english'):
            new_words.append(word)
    return new_words

def stem_words(words):
    """Stem words in list of tokenized words"""
    stemmer = LancasterStemmer()
    stems = []
    for word in words:
        stem = stemmer.stem(word)
        stems.append(stem)
    return stems

def lemmatize_verbs(words):
    """Lemmatize verbs in list of tokenized words"""
    lemmatizer = WordNetLemmatizer()
    lemmas = []
    for word in words:
        lemma = lemmatizer.lemmatize(word, pos='v')
        lemmas.append(lemma)
    return lemmas

def normalize(words):
    words = remove_non_ascii(words)
    words = to_lowercase(words)
    words = remove_punctuation(words)
    words = replace_numbers(words)
    words = remove_stopwords(words)
    return words

words = normalize(words)
# print(words)

# %%
def stem_and_lemmatize(words):
    stems = stem_words(words)
    lemmas = lemmatize_verbs(words)
    return stems, lemmas

stems, lemmas = stem_and_lemmatize(words)
print('Stemmed:\n', stems)
print('\nLemmatized:\n', lemmas)
# Out:
# Stemmed:
#  ['giv', 'blood', 'yo', 'today', 'lik', 'join', 'elit', 'hyperexclud', 'club', 'pap', 'know', 'gay', 'men', 'elig', 'don', 'blood', 'stop', 'try', 'pap', 'know', 'elig', 'giv', 'blood', 'stop', 'try', 'heal', 'lgbtq', 'eq', 'gay', 'memoir', 'mean', 'don', 'blood', 'gay', 'man', 'americ', 'venezuel', 'ang', 'econom', 'ineq', 'fuel', 'ris', 'strongman', 'powerhungry', 'milit', 'act', 'interest', 'undermin', 'democr', 'institut', 'could', 'hap', 'yo', 'institut', 'protect', 'peopl', 'chos', 'pow', 'weal', 'instead', 'could', 'hap', 'yo', 'venezuel', 'govern', 'polit', 'econom', 'donaldtrump', 'cris', 'venezuel', 'tel', 'us', 'democr', 'peopl', 'thrive', 'tak', 'adv', 'every', 'chant', 'optim', 'person', 'decid', 'big', 'smal', 'on', 'peopl', 'efficy', 'mat', 'perspect', 'money', 'simpl', 'complex', 'machinelearn', 'fight', 'complex', 'bia', 'ten', 'year', 'serv', 'op', 'iraq', 'freedom', 'upd', 'is', 'lead', 'chang', 'iraq', 'mak', 'quest', 'everyth', 'try', 'mak', 'sens', 'war', 'exerc', 'futil', 'vonnegut', 'dresd', 'fallujah', 'vet', 'war', 'lif', 'iraq', 'kurtvonnegut', 'mak', 'sens', 'tim', 'war', 'cash', 'netflix', 'audy', 'ide', 'stil', 'rot', 'netflix', 'appl', 'predict', 'busy', 'analys', 'eight', 'reason', 'appl', 'buy', 'netflix', 'new', 'smartphon', 'tech', 'work', 'tech', 'huawe', 'smartphon', 'camera', 'android', 'next', 'phon', 'may', 'hol', 'screen', 'custom', 'wil', 'pay', 'upward', 'one thousand', 'phon', 'reward', 'envy', 'friend', 'cowork', 'lat', 'appl', 'design', 'seem', 'undermin', 'busy', 'custom', 'wil', 'pay', 'upward', 'one thousand', 'phon', 'reward', 'much', 'stat', 'appl', 'busy', 'psycholog', 'econom', 'productm', 'simpl', 'psycholog', 'behind', 'appl', 'fal', 'chant', 'meet', 'man', 'idl', 'machin', 'man', 'lot', 'idea', 'would', 'giv', 'ris', 'on', 'icon', 'piec', 'workout', 'equip', 'ev', 'inv', 'cult', 'phenomenon', 'untold', 'origin', 'story', 'icon', 'workout', 'machin', 'told', 'on', 'step', 'tim', 'fit', 'oprah', 'exerc', 'hist', 'market', 'oil', 'oprah', 'or', 'hist', 'stairmast', 'smal', 'group', 'welleduc', 'profess', 'enjoy', 'ris', 'wag', 'work', 'toil', 'loww', 'job', 'chant', 'adv', 'technolog', 'econom', 'work', 'ineq', 'tech', 'splitting', 'yo', 'workforc', 'two', 'gre', 'new', 'cre', 'follow', 'step', 'find', 'in', 'writ', 'compos', 'fingerpaint', 'chef', 'lyr', 'entrepr', 'cre', 'produc', 'self', 'howto', 'cre', 'auth', 'vir', 'nat', 'sery', 'serv', 'confidencebuild', 'adv', 'writ', 'shar', 'method', 'work', 'twenty-five', 'year', 'writ', 'enco', 'guid', 'distil', 'year', 'auth', 'writ', 'cre', 'produc', 'publ', 'work', 'twenty-five', 'tip', 'becom', 'writ', 'everyon', 'seem', 'tidy', 'mary', 'kondo', 'minim', 'trend', 'overshadow', 'valu', 'art', 'cre', 'nat', 'tend', 'messy', 'maxim', 'cam', 'lov', 'maxim', 'minim', 'world', 'konmar', 'mariekondo', 'cre', 'art', 'selfhelp', 'car', 'mary', 'kondo', 'think', 'spac', 'link', 'work', 'interest', 'harm', 'good', 'car', 'pass', 'work', 'fixedmindset', 'growthmindset', 'tru', 'find', 'satisfy', 'car', 'socy', 'lean', 'heavy', 'simpl', 'cre', 'simpl', 'bia', 'anyth', 'straightforward', 'comb', 'trend', 'cre', 'advert', 'embrac', 'complex', 'idea', 'solv', 'advert', 'simpl', 'bia', 'undermin', 'divers', 'kil', 'cre', 'simpl', 'digitalmarket', 'market', 'brand', 'brandingstrategy', 'simpl', 'bad', 'keep', 'thing', 'get', 'control', 'expand', 'lik', 'crazy', 'startup', 'grow', 'man', 'officecult', 'commun', 'three', 'disast', 'avoid', 'grow', 'startup', 'lot', 'startup', 'prom', 'idea', 'funda', 'problem', 'afford', 'seem', 'beyond', 'reach', 'hous', 'technolog', 'startup', 'city', 'busy', 'technolog', 'fix', 'hous', 'cris', 'two thousand and nineteen', 'may', 'fin', 'year', 'search', 'engin', 'track', 'priv', 'surveil', 'duckduckgo', 'tech', 'googl', 'noth', 'stop', 'googl', 'duckduckgo', 'try', 'anyway', 'frust', 'revers', 'int', 'fast', 'grow', 'found', 'crit', 'invest', 'model', 'built', 'tech', 'industry', 'venturecapit', 'startup', ' ...
#
# Lemmatized:
#  ['give', 'blood', 'yous', 'today', 'like', 'join', 'elite', 'hyperexclusive', 'club', 'paper', 'know', 'gay', 'men', 'eligible', 'donate', 'blood', 'stop', 'try', 'paper', 'know', 'eligible', 'give', 'blood', 'stop', 'try', 'health', 'lgbtq', 'equality', 'gay', 'memoir', 'mean', 'donate', 'blood', 'gay', 'man', 'america', 'venezuela', 'anger', 'economic', 'inequality', 'fuel', 'rise', 'strongman', 'powerhungry', 'military', 'act', 'interest', 'undermine', 'democratic', 'institutions', 'could', 'happen', 'yous', 'institutions', 'protect', 'people', 'choose', 'power', 'wealth', 'instead', 'could', 'happen', 'yous', 'venezuela', 'government', 'politics', 'economics', 'donaldtrump', 'crisis', 'venezuela', 'tell', 'us', 'democracy', 'people', 'thrive', 'take', 'advantage', 'every', 'chance', 'optimize', 'personal', 'decisions', 'big', 'small', 'one', 'people', 'efficiency', 'matter', 'perspective', 'money', 'simplicity', 'complexity', 'machinelearning', 'fight', 'complexity', 'bias', 'ten', 'years', 'serve', 'operation', 'iraqi', 'freedom', 'update', 'isis', 'leadership', 'change', 'iraq', 'make', 'question', 'everything', 'try', 'make', 'sense', 'war', 'exercise', 'futility', 'vonnegut', 'dresden', 'fallujah', 'veterans', 'war', 'life', 'iraq', 'kurtvonnegut', 'make', 'sense', 'time', 'war', 'cash', 'netflix', 'audience', 'idea', 'still', 'rotten', 'netflix', 'apple', 'predictions', 'business', 'analysis', 'eight', 'reason', 'apple', 'buy', 'netflix', 'new', 'smartphone', 'tech', 'work', 'tech', 'huawei', 'smartphones', 'cameras', 'android', 'next', 'phone', 'may', 'hole', 'screen', 'customers', 'will', 'pay', 'upwards', 'one thousand', 'phone', 'reward', 'envy', 'friends', 'coworkers', 'lately', 'apple', 'design', 'seem', 'undermine', 'business', 'customers', 'will', 'pay', 'upwards', 'one thousand', 'phone', 'reward', 'much', 'status', 'apple', 'business', 'psychology', 'economics', 'productmanagement', 'simple', 'psychology', 'behind', 'apple', 'fall', 'chance', 'meet', 'man', 'idle', 'machine', 'man', 'lot', 'ideas', 'would', 'give', 'rise', 'one', 'iconic', 'piece', 'workout', 'equipment', 'ever', 'invent', 'cultural', 'phenomenon', 'untold', 'origin', 'story', 'iconic', 'workout', 'machine', 'tell', 'one', 'step', 'time', 'fitness', 'oprah', 'exercise', 'history', 'market', 'oil', 'oprah', 'oral', 'history', 'stairmaster', 'small', 'group', 'welleducated', 'professionals', 'enjoy', 'rise', 'wag', 'workers', 'toil', 'lowwage', 'job', 'chance', 'advance', 'technology', 'economics', 'work', 'inequality', 'tech', 'split', 'yous', 'workforce', 'two', 'great', 'news', 'creator', 'follow', 'step', 'find', 'inner', 'writer', 'composer', 'fingerpainter', 'chef', 'lyricist', 'entrepreneur', 'creativity', 'productivity', 'self', 'howto', 'creative', 'author', 'viral', 'nation', 'series', 'serve', 'confidencebuilding', 'advice', 'writers', 'share', 'methods', 'work', 'twenty-five', 'years', 'write', 'encouragement', 'guidance', 'distil', 'years', 'author', 'write', 'creativity', 'productivity', 'publish', 'work', 'twenty-five', 'tip', 'become', 'writer', 'everyone', 'seem', 'tidy', 'marie', 'kondo', 'minimalism', 'trend', 'overshadow', 'value', 'artists', 'creatives', 'naturally', 'tendency', 'messiness', 'maximalism', 'come', 'love', 'maximalist', 'minimalist', 'world', 'konmari', 'mariekondo', 'creativity', 'art', 'selfhelp', 'care', 'marie', 'kondo', 'think', 'space', 'link', 'work', 'interest', 'harm', 'good', 'career', 'passion', 'work', 'fixedmindset', 'growthmindset', 'truth', 'find', 'satisfy', 'career', 'society', 'lean', 'heavily', 'simple', 'create', 'simplicity', 'bias', 'anything', 'straightforward', 'combat', 'trend', 'creative', 'advertise', 'embrace', 'complex', 'ideas', 'solutions', 'advertise', 'simplicity', 'bias', 'undermine', 'diversity', 'kill', 'creativity', 'simplicity', 'digitalmarketing', 'market', 'brand', 'brandingstrategy', 'simple', 'bad', 'keep', 'things', 'get', 'control', 'expand', 'like', 'crazy', 'sta ...

# %%
# Perform all the functions

# %%
vect = TfidfVectorizer(max_features=1200, lowercase=True, analyzer="word", stop_words="english", ngram_range=(1,1))
vect.fit_transform(stems)
# Out:
# <1083x579 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1013 stored elements in Compressed Sparse Row format>

# %%
len(vect.get_feature_names())
# Out:
# 579

# %%
len(stems)
# Out:
# 1083

# %%
#transform content to lower case
df_tags["content"] = df_tags["content"].apply(lambda x: " ".join(y.lower() for y in x.split()))

# removing punctuation
df_tags["content"] = df_tags["content"].str.replace('[^\w\s]', '')

# removal of stopwords
df_tags["content"] = df_tags["content"].apply(lambda x: " ".join(y for y in x.split() if y not in stop))

#common word removal
# freq = list(pd.Series(' '.join(df_tags["content"]).split()).value_counts()[:10].index)
# df_tags["content"] = df_tags["content"].apply(lambda x: " ".join(y for y in x.split() if y not in freq))

#Rare words removal
# freq = list(pd.Series(" ".join(df_tags["content"]).split()).value_counts()[-10:].index)
# df_tags['content'] = df_tags["content"].apply(lambda x: " ".join( y for y in x.split() if y not in freq))

# spelling correction
df_tags["content"] = df_tags["content"].apply(lambda x: str(TextBlob(x).correct()))

# Tokenization
# TextBlob(df_tags["content"][0]).words

#stemming
# df_tags["content"] = df_tags["content"].apply(lambda x: " ".join([stem(y) for y in x.split()]))

#Lemmatization
df_tags["content"] = df_tags["content"].apply(lambda x: " ".join([Word(word).lemmatize() for word in x.split()]))

# %% [markdown]
# ## Text processing with TfIdf and count vector

# %%
## Adv Text Processing

#N-gram N=2
# ngramVec = df_tags["content"].apply(lambda x: TextBlob(x).ngrams(2))

# Term Frequency
# tf1 = df_tags["content"].apply(lambda x: pd.value_counts(x.split(" "))).sum(axis=0).reset_index()
# tf1.columns = ["words", "tf"]

# # Inverse document frequency
# for i, word in enumerate(tf1["words"]):
#     tf1.loc[i, 'idf'] = np.log(df_tags.shape[0]/(len(df_tags[df_tags["content"].str.contains(word)])))


# Term frequency and inverse document frequency
# tf1["tfidf"] = tf1["tf"]*tf1["idf"]


# Term frequency and inverse document frequency with sklearn lib
tfidf = TfidfVectorizer(max_features=450, lowercase=True, analyzer="word", stop_words="english", ngram_range=(1,1))
tfidf_vect = tfidf.fit_transform(df_tags["content"])

df_tfidf = pd.DataFrame(tfidf_vect.toarray())
df_tfidf.columns = tfidf.get_feature_names()

# merge columns with tfidf
df_tags_process = df_tags.merge(df_tfidf, left_index=True, right_index=True)

#Bag of words
# bow = CountVectorizer(max_features=300, lowercase=True, analyzer="word", ngram_range=(1,1))
# train_bow = bow.fit_transform(df_tags["content"])
# bow.get_feature_names()

#Sentiment analysis
df_tags_process["sentiment"] = df_tags["raw_data"].apply(lambda x: TextBlob(x).sentiment[0])
df_tags_process = df_tags_process.drop(["content", "raw_data"], axis=1)

# %% [markdown]
# ## Similarity of a matrix with pearson and cosine

# %%
df_similarity = df_tags.drop(["content", "raw_data"], axis=1)

## pearson correlation with pandas dataframe
df_pearsonr = df_similarity.transpose().corr(method='pearson', min_periods=1)  # [1].sort_values(ascending=False)
## cosine similarity  correlation
cosine_sim = cosine_similarity(df_similarity, df_similarity)       #pd.Series( [1]).sort_values(ascending=False)

# %%
# cosine_sim finding with index
cosine_values = pd.Series(cosine_sim[1]).sort_values(ascending=False)
pearson_values = df_pearsonr[1].sort_values(ascending=False)

# %%
for i in range(0, 42):
    print(round(cosine_values[i]-pearson_values[i], 6))
# Out:
# -1e-06
# 0.0
# -1e-06
# -1e-06
# -1e-06
# 0.0
# 0.0
# 0.0
# -0.0
# 1e-06
# -1e-06
# -1e-06
# -0.0
# 0.0
# 1e-06
# 1e-06
# 3e-06
# 1e-06
# 0.0
# 2e-06
# 0.0
# -0.0
# 1e-06
# -0.0
# -1e-06
# 0.0
# 0.0
# -2e-06
# -1e-06
# -0.0
# -0.0
# 0.0
# 1e-06
# 1e-06
# 1e-06
# 2e-06
# -3e-06
# 4e-06
# 1e-06
# -0.0
# 1e-06
# 1e-06

# %%
# pd.Series(cosine_similarity(df_similarity, df_similarity)[1]).sort_values(ascending=False)

# blogs
df_tags_cnt22 = lambda x: " ".join([y for y in x.split() if not y.isdigit()])

# %%
# len(df_tags.columns)
views
df_tags_cnt22(df_tags["content"][22])
df_tags["content"][22].split()
# Out:
# ['It',
#  'is',
#  '1997.',
#  'It',
#  'is',
#  '2017.',
#  'It',
#  'doesn’t',
#  'matter.',
#  'It',
#  'is',
#  'both.',
#  'In',
#  'years,',
#  'my',
#  'life',
#  'has',
#  'come',
#  'full',
#  'circle,',
#  'degrees',
#  'for',
#  'real.',
#  'At',
#  '47,',
#  'my',
#  'life',
#  'looks',
#  'uncannily',
#  'the',
#  'same',
#  'way',
#  'it',
#  'did',
#  'at',
#  '27.',
#  'Post-divorce,',
#  'I’ve',
#  'returned',
#  'to',
#  'my',
#  'old',
#  'ways',
#  'aging',
#  'adulthood',
#  'dating',
#  'self',
#  'culture',
#  'My',
#  'Life',
#  'at',
#  'Is',
#  'Back',
#  'to',
#  'What',
#  'It',
#  'Was',
#  'Like',
#  'at']

# %%
# pearsonr = np.corrcoef(df_similarity)[0]
# pearsonr.sort()

# df_tags['content'][18]

from nltk.tokenize import RegexpTokenizer

tokenizer = RegexpTokenizer(r'\!()-[]{};:'"\,<>./?@#$%^&*_~+')
tokenizer.tokenize('Eighty-seven miles to go, yet.  Onward!')
# Out:
#   File "<ipython-input-74-f1d04bb67996>", line 8
#     tokenizer = RegexpTokenizer(r'\!()-[]{};:'"\,<>./?@#$%^&*_~+')
#                                                                   ^
# SyntaxError: EOL while scanning string literal

# %%
# df_similarity.corr(method='pearson', min_periods=1)

# define punctuation
punctuations = '''!()-[]{};:'"\,<>./?@#$%^&*_~'''

my_str = "Hello!!!, he said ---and went."

# To take input from the user
# my_str = input("Enter a string: ")

# remove punctuation from the string
no_punct = ""
for char in my_str:
   if char not in punctuations:
       no_punct = no_punct + char

# display the unpunctuated string
print(no_punct)

# %%
"90".isdigit()
# Out:
# True

# %%
blogs_db.insert_many(data_many)

# %%
df_tags_process = df_tags_process.drop(["content", "raw_data"], axis=1)

# %%
df_tags_process.columns[-10:]
# Out:
# Index(['workethic', 'workforce', 'workstech', 'worldkonmari', 'writer',
#        'wrote', 'year', 'youprivacy', 'yoursdesign', 'sentiment'],
#       dtype='object')

# %%
db.content_similarity.insert_many(list(df_tags_process.T.to_dict().values()))

# %%
db.content_similarity
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'Blog_Recommendation'), 'content_similarity')

# %%
bson.son.SON({})
# Out:
# SON([])

# %%
tfidf.get_feature_names()
# Out:
# ['1000',
#  '1997',
#  '20',
#  '2016',
#  '2017',
#  '2018',
#  '2019',
#  '25',
#  '27',
#  '360',
#  '47',
#  '780000',
#  'adulthood',
#  'advance',
#  'advantage',
#  'advertising',
#  'advice',
#  'aesthetic',
#  'afford',
#  'ago',
#  'anger',
#  'apple',
#  'art',
#  'author',
#  'available',
#  'avoid',
#  'awkward',
#  'axillary',
#  'bad',
#  'barrier',
#  'base',
#  'basic',
#  'basicincome',
#  'believe',
#  'better',
#  'bias',
#  'big',
#  'bland',
#  'blood',
#  'blossom',
#  'bowl',
#  'build',
#  'business',
#  'canon',
#  'care',
#  'career',
#  'cash',
#  'chance',
#  'cigarette',
#  'commerce',
#  'communicating',
#  'communication',
#  'community',
#  'company',
#  'complex',
#  'complexity',
#  'composer',
#  'compromise',
#  'concept',
#  'confidencebuilding',
#  'confirmation',
#  'conservative',
#  'conspiracy',
#  'conspiracytheories',
#  'control',
#  'conversation',
#  'copying',
#  'counterpart',
#  'couture',
#  'covering',
#  'cowardly',
#  'crazy',
#  'creating',
#  'creative',
#  'creativity',
#  'creator',
#  'credit',
#  'crisis',
#  'criticizing',
#  'crush',
#  'cultural',
#  'culture',
#  'customer',
#  'cystic',
#  'daddy',
#  'dark',
#  'darkness',
#  'database',
#  'dating',
#  'deaf',
#  'death',
#  'decision',
#  'deeply',
#  'deeprooted',
#  'degree',
#  'democracy',
#  'democratic',
#  'design',
#  'digitalmarketing',
#  'disability',
#  'disagree',
#  'disaster',
#  'dislike',
#  'disruption',
#  'distilled',
#  'diversity',
#  'doctor',
#  'doesn',
#  'donaldtrump',
#  'donate',
#  'dont',
#  'dresden',
#  'duckduckgo',
#  'dying',
#  'earth',
#  'economic',
#  'economics',
#  'economy',
#  'efficiency',
#  'election',
#  'eligible',
#  'elite',
#  'em',
#  'embarrassing',
#  'embrace',
#  'emulation',
#  'encountered',
#  'encouragement',
#  'engine',
#  'enjoys',
#  'entirely',
#  'entrepreneur',
#  'envy',
#  'epidemic',
#  'equality',
#  'exercise',
#  'expert',
#  'fantasy',
#  'fat',
#  'feeling',
#  'feminist',
#  'finance',
#  'flat',
#  'flight',
#  'friend',
#  'future',
#  'gaping',
#  'gay',
#  'good',
#  'goose',
#  'group',
#  'groupthink',
#  'growth',
#  'happen',
#  'hate',
#  'health',
#  'healthcare',
#  'help',
#  'history',
#  'housing',
#  'idea',
#  'income',
#  'industry',
#  'inequality',
#  'institution',
#  'internet',
#  'ironic',
#  'job',
#  'kind',
#  'know',
#  'lately',
#  'leadership',
#  'left',
#  'let',
#  'letter',
#  'life',
#  'like',
#  'livelihood',
#  'lookout',
#  'lost',
#  'lot',
#  'love',
#  'machine',
#  'make',
#  'making',
#  'man',
#  'marie',
#  'marketing',
#  'matter',
#  'mean',
#  'medium',
#  'mental',
#  'million',
#  'minimalist',
#  'model',
#  'money',
#  'moon',
#  'moral',
#  'movement',
#  'narrative',
#  'nation',
#  'naturally',
#  'nearly',
#  'necessarily',
#  'need',
#  'neoliberal',
#  'netflix',
#  'new',
#  'news',
#  'night',
#  'northwest',
#  'note',
#  'observation',
#  'october',
#  'officeculture',
#  'oil',
#  'okay',
#  'old',
#  'open',
#  'operation',
#  'optimism',
#  'oral',
#  'origin',
#  'outsmart',
#  'overshadow',
#  'pale',
#  'paper',
#  'paranoid',
#  'park',
#  'partner',
#  'passenger',
#  'passion',
#  'patient',
#  'pay',
#  'paying',
#  'people',
#  'person',
#  'personal',
#  'perspective',
#  'phenomenon',
#  'phone',
#  'piece',
#  'place',
#  'plagued',
#  'plane',
#  'play',
#  'political',
#  'politics',
#  'porch',
#  'portal',
#  'post',
#  'postdivorce',
#  'power',
#  'powerful',
#  'powerhungry',
#  'prediction',
#  'premium',
#  'presentable',
#  'privacy',
#  'problem',
#  'product',
#  'productdesign',
#  'productivity',
#  'productmanagement',
#  'professional',
#  'profound',
#  'promising',
#  'protected',
#  'psychology',
#  'publishing',
#  'question',
#  'quick',
#  'raging',
#  'rallied',
#  'ran',
#  'reach',
#  'ready',
#  'real',
#  'really',
#  'reason',
#  'recordkeeping',
#  'register',
#  'relationship',
#  'releasing',
#  'remove',
#  'reporter',
#  'resuscitated',
#  'retail',
#  'returned',
#  'reverse',
#  'rewarded',
#  'right',
#  'rise',
#  'rising',
#  'risk',
#  'rode',
#  'role',
#  'rope',
#  'rotten',
#  'ruin',
#  'ruining',
#  'rule',
#  'satire',
#  'satisfying',
#  'saved',
#  'say',
#  'science',
#  'screen',
#  'sea',
#  'search',
#  'seat',
#  'sectional',
#  'self',
#  'selfcheckout',
#  'selfhelp',
#  'selfimprovement',
#  'sense',
#  'serf',
#  'series',
#  'served',
#  'service',
#  'servicedesign',
#  'share',
#  'shared',
#  'sharp',
#  'shipper',
#  'shouldn',
#  'showed',
#  'shrinking',
#  'silicon',
#  'siliconvalley',
#  'simple',
#  'simplicity',
#  'slender',
#  'small',
#  'smallscale',
#  'smartphone',
#  'smartphones',
#  'smoking',
#  'social',
#  'socialmedia',
#  'society',
#  'softly',
#  'software',
#  'solution',
#  'space',
#  'spark',
#  'speak',
#  'splitting',
#  'sprawling',
#  'stairmaster',
#  'started',
#  'status',
#  'step',
#  'stop',
#  'story',
#  'straightforward',
#  'strategy',
#  'strictly',
#  'strongman',
#  'struck',
#  'study',
#  'success',
#  'successful',
#  'sugar',
#  'sugardaddy',
#  'super',
#  'superbowl',
#  'superstore',
#  'surveillance',
#  'taking',
#  'tank',
#  'teach',
#  'technology',
#  'tell',
#  'telling',
#  'tendency',
#  'testing',
#  'theory',
#  'thing',
#  'think',
#  'thought',
#  'thrive',
#  'throw',
#  'tiding',
#  'time',
#  'tip',
#  'today',
#  'toil',
#  'told',
#  'tool',
#  'totally',
#  'track',
#  'tramp',
#  'travel',
#  'treasure',
#  'trend',
#  'true',
#  'truth',
#  'try',
#  'trying',
#  'tucked',
#  'turn',
#  'twitter',
#  'uncanny',
#  'undermine',
#  'undermining',
#  'unfamiliar',
#  'universal',
#  'universalbasicincome',
#  'untold',
#  'updated',
#  'upwards',
#  'urban',
#  'used',
#  'userexperience',
#  'valley',
#  'value',
#  'venezuela',
#  'venture',
#  'venturecapital',
#  'veteran',
#  'vision',
#  'vital',
#  'vonnegut',
#  'wage',
#  'wall',
#  'want',
#  'war',
#  'water',
#  'wave',
#  'way',
#  'wealth',
#  'weed',
#  'week',
#  'welleducated',
#  'willing',
#  'window',
#  'wise',
#  'wont',
#  'work',
#  'worked',
#  'worker',
#  'workethic',
#  'workforce',
#  'world',
#  'worldwide',
#  'writer',
#  'writing',
#  'year']

# %%
tfidf.get_feature_names()
# Out:
# ['1000',
#  '1cb6b5a58072companies',
#  '1e11a13afbecif',
#  '1e11a13afbecpostdivorce',
#  '255075e61b5f2019',
#  '27',
#  '2879ca55026aefficiency',
#  '29927d35d476how',
#  '2abb3ee3a489when',
#  '324326475b88and',
#  '36bb350e8f70better',
#  '36bb350e8f70credit',
#  '3a2108752087he',
#  '41e48b43404fif',
#  '441cd3efcd54how',
#  '47',
#  '486aefe3d462the',
#  '5254bd738dcdecigarettes',
#  '56ad0b00a091the',
#  '64c49bd92b9ethe',
#  '64dc0564597athe',
#  '6dedc06fe4e4what',
#  '73720195c226vonnegut',
#  '78e429aad85ait',
#  '799bdc99a0fdencouragement',
#  '7bcec4b8c02ea',
#  '7bcec4b8c02eget',
#  '7bcec4b8c02ei',
#  '7da2a328fd85great',
#  '88325be720b4lets',
#  '890b995a50b5people',
#  '96d8c816c5dbcustomers',
#  '9cca1cc5944fheres',
#  'a8634106cb64on',
#  'add55d826321sometimes',
#  'addictionexperts',
#  'adsadvertising',
#  'adulthood',
#  'advancetechnology',
#  'advertising',
#  'advice',
#  'aesthetic',
#  'afc1ff39833eembarrassing',
#  'afford',
#  'affordability',
#  'age',
#  'agriculture',
#  'america',
#  'analysis',
#  'androidyour',
#  'anger',
#  'anniversary',
#  'anxietiespolitics',
#  'apple',
#  'art',
#  'audience',
#  'audiencetargeting',
#  'authorwriting',
#  'avoid',
#  'b42354b051f1a',
#  'b42354b051f1frustrated',
#  'b5f15686d60its',
#  'b5f15686d60when',
#  'bad',
#  'basic',
#  'basicincome',
#  'be6e6bf82e72notes',
#  'believe',
#  'better',
#  'bias',
#  'biasespsychology',
#  'big',
#  'bland',
#  'blood',
#  'bodypositive',
#  'bond',
#  'book',
#  'bowl',
#  'branding',
#  'brandingstrategysimple',
#  'build',
#  'built',
#  'business',
#  'businessmore',
#  'businesswhy',
#  'buy',
#  'came',
#  'camera',
#  'capitalismthe',
#  'capitalist',
#  'card',
#  'care',
#  'career',
#  'carlton',
#  'case',
#  'cash',
#  'cessation',
#  'chance',
#  'checkout',
#  'chef',
#  'chose',
#  'cigarette',
#  'city',
#  'close',
#  'communicating',
#  'communication',
#  'community',
#  'company',
#  'complexity',
#  'composer',
#  'compromise',
#  'conservative',
#  'conspiracytheories',
#  'control',
#  'conversation',
#  'counterpartgroupfeel',
#  'covering',
#  'cowardly',
#  'crazystartup',
#  'creative',
#  'creativity',
#  'creativitysimplicity',
#  'creator',
#  'crisis',
#  'criticizing',
#  'crush',
#  'culture',
#  'd0d0829b944why',
#  'd9976adb8a68reporters',
#  'da330706e6c9i',
#  'daddy',
#  'dark',
#  'dating',
#  'deaf',
#  'design',
#  'disruption',
#  'doesn',
#  'dresden',
#  'duckduckgo',
#  'dying',
#  'e16953e3e9ahow',
#  'earth',
#  'economics',
#  'economiesbasicincome',
#  'eligible',
#  'em',
#  'embrace',
#  'encountered',
#  'engine',
#  'equality',
#  'equalitythe',
#  'fantasy',
#  'fat',
#  'feminist',
#  'flat',
#  'flawedtech',
#  'flight',
#  'follow',
#  'form',
#  'founder',
#  'friend',
#  'friendship',
#  'fuckboys',
#  'fundamental',
#  'future',
#  'gaping',
#  'gay',
#  'getting',
#  'good',
#  'goodcareers',
#  'googlenothing',
#  'goose',
#  'got',
#  'government',
#  'ground',
#  'group',
#  'groupthink',
#  'growing',
#  'growth',
#  'growthmindsetthe',
#  'guidance',
#  'happen',
#  'harm',
#  'hasn',
#  'hate',
#  'hatred',
#  'health',
#  'healthy',
#  'hearingand',
#  'help',
#  'history',
#  'hole',
#  'housing',
#  'howtohow',
#  'huawei',
#  'humiliated',
#  'husband',
#  'icon',
#  'idea',
#  'imagineartificialintelligence',
#  'important',
#  'inaccessibility',
#  'incentive',
#  'income',
#  'industry',
#  'inequalitytech',
#  'inner',
#  'instead',
#  'institution',
#  'internet',
#  'internetborn',
#  'internetculturehow',
#  'investment',
#  'ironic',
#  'isolation',
#  'job',
#  'killing',
#  'kind',
#  'know',
#  'kurtvonnegutmaking',
#  'leadership',
#  'left',
#  'legend',
#  'lend',
#  'lending',
#  'letter',
#  'lgbtq',
#  'life',
#  'lifelessonswhy',
#  'like',
#  'linking',
#  'livelihood',
#  'lookout',
#  'lost',
#  'lot',
#  'love',
#  'lowwage',
#  'lyricist',
#  'machine',
#  'machinelearninghow',
#  'make',
#  'man',
#  'management',
#  'marie',
#  'mariekondo',
#  'marijuana',
#  'marketing',
#  'marketingfrom',
#  'marriage',
#  'matter',
#  'maximalist',
#  'mean',
#  'mediatrump',
#  'memoirwhat',
#  'mental',
#  'mentalhealth',
#  'message',
#  'minimalist',
#  'model',
#  'money',
#  'moneyhow',
#  'moral',
#  'movement',
#  'narrative',
#  'necessarily',
#  'need',
#  'netflix',
#  'new',
#  'news',
#  'officeculture',
#  'oil',
#  'okay',
#  'old',
#  'onepolitics',
#  'oral',
#  'orcreativity',
#  'origin',
#  'outsmart',
#  'paper',
#  'paranoid',
#  'partner',
#  'passenger',
#  'passion',
#  'patientshealthcare',
#  'pay',
#  'people',
#  'person',
#  'personpsychology',
#  'perspectivemoney',
#  'phone',
#  'play',
#  'political',
#  'politics',
#  'politicswhy',
#  'porch',
#  'power',
#  'powerful',
#  'prediction',
#  'problem',
#  'problemsecommerce',
#  'product',
#  'productdesignhealthcare',
#  'productivity',
#  'productmanagement',
#  'productmanagementthe',
#  'professional',
#  'profound',
#  'promising',
#  'protected',
#  'psychology',
#  'publishing',
#  'qanonqanon',
#  'question',
#  'quick',
#  'ran',
#  'reachhousing',
#  'ready',
#  'reason',
#  'relationship',
#  'relationshipfinance',
#  'relationshipshave',
#  'retail',
#  'returned',
#  'reverse',
#  'rewarded',
#  'right',
#  'rising',
#  'rolerelationships',
#  'rottennetflix',
#  'ruining',
#  'rule',
#  'saline',
#  'satire',
#  'satisfying',
#  'saved',
#  'science',
#  'screen',
#  'search',
#  'sectional',
#  'self',
#  'selfcheckout',
#  'selfhelpi',
#  'selfimprovement',
#  'selfimprovementhow',
#  'sense',
#  'servicedesign',
#  'shared',
#  'showed',
#  'silicon',
#  'siliconvalley',
#  'simple',
#  'simplicity',
#  'slender',
#  'small',
#  'smallscale',
#  'smartphone',
#  'smartphones',
#  'smoking',
#  'socialmedia',
#  'society',
#  'softly',
#  'space',
#  'splitting',
#  'stairmaster',
#  'started',
#  'startupemulation',
#  'startupwhy',
#  'status',
#  'statusapple',
#  'step',
#  'stop',
#  'story',
#  'storyfiction',
#  'strategy',
#  'strictly',
#  'study',
#  'success',
#  'sugar',
#  'sugardaddy',
#  'super',
#  'superbowl',
#  'surveillance',
#  'teach',
#  'technology',
#  'tell',
#  'telling',
#  'themrelationships',
#  'thing',
#  'think',
#  'thought',
#  'throw',
#  'time',
#  'timefitness',
#  'tip',
#  'toil',
#  'told',
#  'tool',
#  'totally',
#  'track',
#  'tramp',
#  'travel',
#  'treasuredeaf',
#  'true',
#  'truth',
#  'trying',
#  'tryinghealth',
#  'tucked',
#  'undermining',
#  'unfamiliar',
#  'universal',
#  'universalbasicincome',
#  'untold',
#  'upwards',
#  'urban',
#  'used',
#  'userexperience',
#  'userexperiencehow',
#  'valley',
#  'value',
#  'valuesadvertising',
#  'vapingvaping',
#  'venezuela',
#  'venture',
#  'vision',
#  'wage',
#  'want',
#  'war',
#  'wave',
#  'way',
#  'wayfaring',
#  'wealth',
#  'weed',
#  'welleducated',
#  'weventurecapital',
#  'willing',
#  'windowsobriety',
#  'wont',
#  'work',
#  'workeconomics',
#  'worked',
#  'worker',
#  'workethic',
#  'workforce',
#  'workstech',
#  'worldkonmari',
#  'writer',
#  'wrote',
#  'year',
#  'youprivacy',
#  'yoursdesign']

# %%
df_tags
# Out:
#                                               content  \
# 0   a8634106cb64on paper know in eligible give blo...
# 1   64dc0564597athe institution protected people c...
# 2   2879ca55026aefficiency matter perspectivemoney...
# 3   73720195c226vonnegut dresden fallujahveterans ...
# 4   78e429aad85ait cash netflix audience idea stil...
# 5   9cca1cc5944fheres new smartphone teach workste...
# 6   96d8c816c5dbcustomers willing pay upwards 1000...
# 7   486aefe3d462the untold origin story ironic loo...
# 8   b42354b051f1a small group welleducated profess...
# 9   7da2a328fd85great news creator follow step fin...
# 10  799bdc99a0fdencouragement guidance distilled y...
# 11  e16953e3e9ahow came love maximalist minimalist...
# 12  d0d0829b944why linking work interest harm good...
# 13  29927d35d476how advertising simplicity bias un...
# 14  441cd3efcd54how keep thing getting control you...
# 15  b42354b051f1a lot status promising idea fundam...
# 16  255075e61b5f2019 may finally year search engin...
# 17  b42354b051f1frustrated reverse incentive fast ...
# 18  41e48b43404fif something worked one company do...
# 19  64c49bd92b9ethe conservative icon got throw we...
# 20  5254bd738dcdecigarettes powerful smoking cessa...
# 21  1e11a13afbecif thought groupthink bad get read...
# 22  1e11a13afbecpostdivorce give returned old wayf...
# 23  7bcec4b8c02eget ready wave bland cowardly supe...
# 24  d9976adb8a68reporters need stop covering he st...
# 25  56ad0b00a091the movement dying right around ti...
# 26  6dedc06fe4e4what internetborn urban legend tel...
# 27  b5f15686d60when want expensive thing partner y...
# 28  b5f15686d60its almost always bad idea ground r...
# 29  da330706e6c9i lost hearingand lot conversation...
# 30  2abb3ee3a489when another passenger humiliated ...
# 31  36bb350e8f70credit card selfcheckout many ques...
# 32  36bb350e8f70better up doctor mean better care ...
# 33  324326475b88and five way outsmart mental biase...
# 34  1cb6b5a58072companies know even imagineartific...
# 35  3a2108752087he art show yousoftboy fuckboys da...
# 36  add55d826321sometimes stop communicating much ...
# 37  afc1ff39833eembarrassing fantasy relationship ...
# 38  890b995a50b5people form quick close bond share...
# 39  be6e6bf82e72notes ethic workeconomics basicinc...
# 40  88325be720b4lets build community livelihood sm...
# 41  7bcec4b8c02ea totally sectional essentially tr...
# 42  7bcec4b8c02ei love silicon valley deeply flawe...
#
#                                              raw_data  word_count  char_count  \
# 0   a8634106cb64On paper, I know why I’m not eligi...          32         185
# 1   64dc0564597aThe institutions that should have ...          31         234
# 2   2879ca55026aEfficiency is a matter of perspect...          14         129
# 3   73720195c226Vonnegut had Dresden, and I had Fa...          17         118
# 4   78e429aad85aIt has the cash, and Netflix has t...          25         168
# 5   9cca1cc5944fHere’s how the new smartphone tech...          20         136
# 6   96d8c816c5dbCustomers are willing to pay upwar...          29         221
# 7   486aefe3d462The untold origin story of an icon...          28         182
# 8   b42354b051f1A small group of well-educated pro...          31         225
# 9   7da2a328fd85Great news! You can be a creator. ...          27         203
# 10  799bdc99a0fdEncouragement and guidance distill...          19         150
# 11  e16953e3e9aHow I came to love being a maximali...          25         162
# 12  d0d0829b944Why linking your work to your inter...          23         169
# 13  29927d35d476How advertising’s simplicity bias ...          16         171
# 14  441cd3efcd54How to keep things from getting ou...          26         195
# 15  b42354b051f1A lot of start-ups have promising ...          27         210
# 16  255075e61b5f2019 may finally be the year for ‘...          25         183
# 17  b42354b051f1Frustrated with the reverse incent...          35         276
# 18  41e48b43404fIf something worked for one compan...          24         183
# 19  64c49bd92b9eThe conservative icon got me to th...          21         160
# 20  5254bd738dcdE-cigarettes are a powerful smokin...          30         217
# 21  1e11a13afbecIf you thought groupthink was bad,...          22         158
# 22  1e11a13afbecPost-divorce, I’ve returned to my ...          23         136
# 23  7bcec4b8c02eGet ready for a wave of bland, cow...          20         145
# 24  d9976adb8a68Reporters need to stop covering hi...          21         147
# 25  56ad0b00a091The movement was dying out right a...          25         186
# 26  6dedc06fe4e4What are internet-born urban legen...          23         217
# 27  b5f15686d60When you want to do expensive thing...          32         208
# 28  b5f15686d60It’s almost always a bad idea, but ...          30         192
# 29  da330706e6c9I lost my hearing—and with it, a l...          26         183
# 30  2abb3ee3a489When another passenger humiliates ...          23         171
# 31  36bb350e8f70Credit cards, self-checkout, and t...          25         202
# 32  36bb350e8f70Better UX for doctors means better...          19         165
# 33  324326475b88And five ways to outsmart your own...          20         152
# 34  1cb6b5a58072Companies will know more about you...          22         186
# 35  3a2108752087He has some art to show yousoftboy...          14         109
# 36  add55d826321Sometimes we stop communicating be...          19         138
# 37  afc1ff39833eEmbarrassing fantasy relationships...          19         154
# 38  890b995a50b5People form quick and close bonds ...          26         201
# 39  be6e6bf82e72Notes on the ethics of workeconomi...          16         147
# 40  88325be720b4Let's build communities, livelihoo...          18         167
# 41  7bcec4b8c02eA Totally Fictional But Essentiall...          15         137
# 42  7bcec4b8c02eI love Silicon Valley, but it’s de...          23         151
#
#     avg_word  stopwords  hashtags  numerics  uppercase
# 0   4.470588         12         0         0          1
# 1   6.580645         10         0         0          0
# 2   8.285714          4         0         0          0
# 3   6.000000          5         0         0          1
# 4   5.760000          7         0         0          0
# 5   5.850000          5         0         0          0
# 6   6.161290         11         0         0          0
# 7   5.535714          7         0         0          0
# 8   6.290323          9         0         0          1
# 9   6.555556          7         0         0          0
# 10  6.947368          7         0         0          0
# 11  5.520000          6         0         0          1
# 12  6.391304          8         0         0          0
# 13  9.750000          2         0         0          0
# 14  6.538462          7         0         0          0
# 15  6.814815          7         0         0          0
# 16  6.360000          3         0         0          0
# 17  6.914286         10         0         0          0
# 18  6.666667          6         0         0          0
# 19  6.666667          5         0         0          0
# 20  6.266667          8         0         0          0
# 21  6.227273          6         0         0          0
# 22  4.956522          5         0         2          0
# 23  6.300000          6         0         0          0
# 24  6.047619          6         0         0          0
# 25  6.480000          6         0         0          0
# 26  8.478261          4         0         0          0
# 27  5.531250         14         0         0          0
# 28  5.433333          9         0         0          0
# 29  6.076923          8         0         0          1
# 30  6.478261          7         0         0          0
# 31  7.120000          9         0         0          0
# 32  7.736842          2         0         0          1
# 33  6.650000          5         0         0          0
# 34  7.500000         10         0         0          0
# 35  6.857143          4         0         0          0
# 36  6.315789          7         0         0          0
# 37  7.157895          3         0         0          0
# 38  6.214286          6         0         0          0
# 39  8.250000          4         0         0          0
# 40  8.333333          1         0         0          0
# 41  8.200000          0         0         0          0
# 42  5.608696          3         0         0          1

# %%
 blogs["tags"][0] + blogs["content"] + blogs["title"] + blogs["subtitle"]
# Out:
# 0     health lgbtq equality gay memoirGiving blood i...
# 1     health lgbtq equality gay memoirIn Venezuela, ...
# 2     health lgbtq equality gay memoirSome people th...
# 3     health lgbtq equality gay memoirTen years afte...
# 4                                                   NaN
# 5                                                   NaN
# 6     health lgbtq equality gay memoirCustomers are ...
# 7     health lgbtq equality gay memoirA chance meeti...
# 8                                                   NaN
# 9                                                   NaN
# 10    health lgbtq equality gay memoirThe author of ...
# 11    health lgbtq equality gay memoirEveryone seems...
# 12                                                  NaN
# 13    health lgbtq equality gay memoirSociety is lea...
# 14                                                  NaN
# 15                                                  NaN
# 16                                                  NaN
# 17                                                  NaN
# 18    health lgbtq equality gay memoirCopying other ...
# 19                                                  NaN
# 20    health lgbtq equality gay memoirSmoking is the...
# 21    health lgbtq equality gay memoirA few weeks ag...
# 22    health lgbtq equality gay memoirIt is 1997. It...
# 23    health lgbtq equality gay memoirFollowing the ...
# 24                                                  NaN
# 25    health lgbtq equality gay memoirThe internet a...
# 26    health lgbtq equality gay memoirQAnon started ...
# 27                                                  NaN
# 28                                                  NaN
# 29    health lgbtq equality gay memoirBecause I’m de...
# 30    health lgbtq equality gay memoirPlanes can be ...
# 31    health lgbtq equality gay memoirThere are many...
# 32    health lgbtq equality gay memoirCluttered data...
# 33                                                  NaN
# 34                                                  NaN
# 35                                                  NaN
# 36    health lgbtq equality gay memoirI haven't been...
# 37                                                  NaN
# 38                                                  NaN
# 39    health lgbtq equality gay memoirOne of the bar...
# 40    health lgbtq equality gay memoirIt's time to t...
# 41    health lgbtq equality gay memoirThe northwest ...
# 42                                                  NaN
# dtype: object

# %%
blogs.fillna("")
# Out:
#           blogid                                            content  \
# 0   2524c43bb922  Giving blood in the U.S. today is like joining...
# 1   e11c38f98977  In Venezuela, anger over economic inequality f...
# 2   6052b0cc43ac  Some people thrive on taking advantage of ever...
# 3    daaaaff085c  Ten years after I served in Operation Iraqi Fr...
# 4    f52733f4666
# 5   bc30074fb93d
# 6   66771889da10  Customers are willing to pay upwards of $1,000...
# 7   ebbcb4723c0e  A chance meeting between a man with idle machi...
# 8   b5b8c7911819
# 9   ecfca5ab7518
# 10  95b0bf768745  The author of the ‘Viral Nation’ series serves...
# 11  2785f6670a42  Everyone seems to be tidying up with Marie Kon...
# 12  d2314d321403
# 13  1381784fd679  Society is leaning heavily on simple, creating...
# 14  1df4de6221ac
# 15  ca4128c693b4
# 16  718eb7391423
# 17  d2bbb86db39b
# 18  cfecdbffce96  Copying other successful companies opens up ri...
# 19  a25946836300
# 20  4d8d2dfeed2d  Smoking is the most preventable cause of death...
# 21  1a0a0f6e69cb  A few weeks ago, someone made an observation o...
# 22  eb7a071b3598  It is 1997. It is 2017. It doesn’t matter. It ...
# 23  bcf0b61ee4f0  Following the 2016 election, many companies ra...
# 24  652c340f4503
# 25  2e42c3206223  The internet and the advent of social media re...
# 26  b3d44075ba87  QAnon started as a cryptic post on 4Chan last ...
# 27  6e63ea497ad3
# 28  a27ba55cd0d5
# 29  ca9cbd5ad6b8  Because I’m deaf, I’m left out of so many conv...
# 30  b0ceb1407c61  Planes can be hostile places for fat passenger...
# 31  b4295a07afdc  There are many ways for a superstore to ruin a...
# 32  eacf251d78ad  Cluttered databases. Clumsy patient portals. A...
# 33  68e14a5f41a4
# 34  40347c6ed448
# 35  7e95e2c7f3e7
# 36  7588781774b3  I haven't been blogging a lot lately. I though...
# 37  d9b3b669a71e
# 38  40f5c988c76a
# 39  eea0907cd0ae  One of the barriers to adopting Universal Basi...
# 40  f93a5aa38c97  It's time to think beyond Universal Basic Inco...
# 41  36fbed0268cf  The northwest wall of the Palo Alto Sea Park s...
# 42  b64c40484774
#
#      createrdate     createrid  \
# 0   1.544250e+12  a8634106cb64
# 1   1.548510e+12  64dc0564597a
# 2   1.539530e+12  2879ca55026a
# 3   1.533730e+12  73720195c226
# 4   1.549490e+12  78e429aad85a
# 5   1.549470e+12  9cca1cc5944f
# 6   1.548930e+12  96d8c816c5db
# 7   1.548890e+12  486aefe3d462
# 8   1.549420e+12  b42354b051f1
# 9   1.549310e+12  7da2a328fd85
# 10  1.547060e+12  799bdc99a0fd
# 11  1.546910e+12   e16953e3e9a
# 12  1.547830e+12   d0d0829b944
# 13  1.535590e+12  29927d35d476
# 14  1.548700e+12  441cd3efcd54
# 15  1.548800e+12  b42354b051f1
# 16  1.547230e+12  255075e61b5f
# 17  1.547250e+12  b42354b051f1
# 18  1.544630e+12  41e48b43404f
# 19  1.548780e+12  64c49bd92b9e
# 20  1.549500e+12  5254bd738dcd
# 21  1.549480e+12  1e11a13afbec
# 22  1.549050e+12  1e11a13afbec
# 23  1.548370e+12  7bcec4b8c02e
# 24  1.548960e+12  d9976adb8a68
# 25  1.544460e+12  56ad0b00a091
# 26  1.534760e+12  6dedc06fe4e4
# 27  1.547160e+12   b5f15686d60
# 28  1.547160e+12   b5f15686d60
# 29  1.544470e+12  da330706e6c9
# 30  1.504850e+12  2abb3ee3a489
# 31  1.534860e+12  36bb350e8f70
# 32  1.500630e+12  36bb350e8f70
# 33  1.545090e+12  324326475b88
# 34  1.545350e+12  1cb6b5a58072
# 35  1.439220e+12  3a2108752087
# 36  1.504640e+12  add55d826321
# 37  1.542820e+12  afc1ff39833e
# 38  1.542820e+12  890b995a50b5
# 39  1.524490e+12  be6e6bf82e72
# 40  1.508900e+12  88325be720b4
# 41  1.537770e+12  7bcec4b8c02e
# 42  1.537800e+12  7bcec4b8c02e
#
#                                              subtitle  \
# 0   On paper, I know why I’m not eligible to give ...
# 1   The institutions that should have protected th...
# 2               Efficiency is a matter of perspective
# 3            Vonnegut had Dresden, and I had Fallujah
# 4   It has the cash, and Netflix has the audience....
# 5            Here’s how the new smartphone tech works
# 6   Customers are willing to pay upwards of $1,000...
# 7   The untold origin story of an iconic workout m...
# 8   A small group of well-educated professionals e...
# 9   Great news! You can be a creator. Follow these...
# 10  Encouragement and guidance distilled from my y...
# 11  How I came to love being a maximalist in a min...
# 12  Why linking your work to your interests can do...
# 13  How advertising’s simplicity bias is undermini...
# 14  How to keep things from getting out of control...
# 15  A lot of start-ups have promising ideas, but t...
# 16  2019 may finally be the year for ‘The Search E...
# 17  Frustrated with the reverse incentives of fast...
# 18  If something worked for one company, that does...
# 19  The conservative icon got me to throw my weed ...
# 20  E-cigarettes are a powerful smoking cessation ...
# 21  If you thought groupthink was bad, get ready f...
# 22         Post-divorce, I’ve returned to my old ways
# 23  Get ready for a wave of bland, cowardly Super ...
# 24  Reporters need to stop covering him as if he’s...
# 25  The movement was dying out right around the ti...
# 26  What are internet-born urban legends telling u...
# 27  When you want to do expensive things with your...
# 28  It’s almost always a bad idea, but a few groun...
# 29  I lost my hearing—and with it, a lot of the co...
# 30  When another passenger humiliates a fat person...
# 31  Credit cards, self-checkout, and too many ques...
# 32  Better UX for doctors means better care for pa...
# 33   And five ways to outsmart your own mental biases
# 34  Companies will know more about you than you ca...
# 35                        He has some art to show you
# 36  Sometimes we stop communicating because we hav...
# 37  Embarrassing fantasy relationships play an imp...
# 38  People form quick and close bonds over shared ...
# 39                        Notes on the ethics of work
# 40  Let's build communities, livelihoods, and smal...
# 41  A Totally Fictional But Essentially True Silic...
# 42      I love Silicon Valley, but it’s deeply flawed
#
#                                                  tags  \
# 0                    health lgbtq equality gay memoir
# 1   venezuela government politics economics donald...
# 2        money simplicity complexity machine-learning
# 3                veterans war life iraq kurt-vonnegut
# 4         netflix apple predictions business analysis
# 5             tech huawei smartphones cameras android
# 6   apple business psychology economics product-ma...
# 7            fitness oprah exercise history marketing
# 8                technology economics work inequality
# 9                 creativity productivity self how-to
# 10    writing creativity productivity publishing work
# 11       konmari marie-kondo creativity art self-help
# 12  careers passion work fixed-mindset growth-mindset
# 13  simplicity digital-marketing marketing brandin...
# 14  startup growth management office-culture commu...
# 15         housing technology startup cities business
# 16        privacy surveillance duckduckgo tech google
# 17  venture-capital startup technology leadership ...
# 18    design technology product-management ux startup
# 19  sobriety marijuana productivity success self-i...
# 20       vaping smoking health e-cigarettes addiction
# 21      groupfeel facts groupthink feelings narrative
# 22                aging adulthood dating self culture
# 23   advertising super-bowl marketing politics values
# 24                 politics mental-health trump media
# 25  science flat-earth social-media psychology int...
# 26  politics technology social-media conspiracy-th...
# 27     relationships sugar-daddy advice finance money
# 28         finance advice relationships money lending
# 29  deaf disability accessibility communication eq...
# 30  travel body-positive feminism equality fat-acc...
# 31  ecommerce ux ux-design service-design user-exp...
# 32  healthcare ux ux-design user-experience produc...
# 33  psychology self bias self-improvement life-les...
# 34  artificial-intelligence advertising audience-t...
# 35              softboy fuckboys dating relationships
# 36          life marriage anniversary love compromise
# 37             relationships crush fantasy love heart
# 38      psychology relationships friendship hate love
# 39  economics basic-income universal-basic-income ...
# 40   basic-income agriculture jobs economics politics
# 41     fiction technology marketing feminism equality
# 42      tech silicon-valley disruption satire startup
#
#                                                 title
# 0   What it Means to Donate Blood as a Gay Man in ...
# 1   What the Crisis in Venezuela Tells Us About De...
# 2                How to Fight Against Complexity Bias
# 3                      Making Sense of My Time at War
# 4               8 Reasons Why Apple Won’t Buy Netflix
# 5       Your Next Phone May Have a Hole in the Screen
# 6           The Simple Psychology Behind Apple’s Fall
# 7   From Oil to Oprah: An Oral History of the Stai...
# 8         Tech Is Splitting the U.S. Workforce in Two
# 9                                  How to Be Creative
# 10                       25 Tips to Becoming a Writer
# 11   I Don’t Care What Marie Kondo Thinks of My Space
# 12        The Truth About Finding a Satisfying Career
# 13                                      Simple Is Bad
# 14  3 Disasters to Avoid When You’re Growing a Sta...
# 15     Why Technology Hasn’t Fixed the Housing Crisis
# 16  Nothing Can Stop Google. DuckDuckGo Is Trying ...
# 17  More Startups Have an Unfamiliar Message for V...
# 18                Emulation Is Not a Product Strategy
# 19                   How Tucker Carlson Saved My Life
# 20    Experts Still Disagree Over the Value of Vaping
# 21                  We Are in a ‘Group Feel’ Epidemic
# 22    My Life at 47 Is Back to What It Was Like at 27
# 23                    Advertising in the Age of Anger
# 24                     Trump Is a Mental Health Story
# 25   How the Internet Made Us Believe in a Flat Earth
# 26  QAnon, Slender Man, and Our Paranoid Surveilla...
# 27                   How to Be an Ethical Sugar Daddy
# 28        Is It Ever Okay to Lend Your Partner Money?
# 29        The Profound Isolation of Being a Deaf Teen
# 30        A Letter from the Fat Person on Your Flight
# 31              How Retail Companies Fail at Checkout
# 32    Healthcare Design Is About More Than Aesthetics
# 33         Why You’re So Bad at Predicting the Future
# 34         A Vision of the Dark Future of Advertising
# 35                  Have You Encountered the Softboy?
# 36                             A Letter to My Husband
# 37                 Why Having a Crush Is Good for You
# 38           How Shared Hatred Helps You Make Friends
# 39          The Moral Case for Universal Basic Income
# 40       Why Basic Jobs Are Better Than Basic Incomes
# 41                                 The Big Disruption
# 42  Why I Left My Big Fancy Tech Job and Wrote a Book
